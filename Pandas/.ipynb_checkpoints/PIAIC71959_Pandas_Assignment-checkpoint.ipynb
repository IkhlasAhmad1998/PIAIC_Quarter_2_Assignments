# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
us_census = pd.concat([pd.read_csv(f, index_col=0) for f in glob.glob('states*.csv')], ignore_index=True)

# %%
us_census
# Out:
#                    State  TotalPop             Hispanic                White  \
# 0                Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1                 Alaska    733375   5.909580838323351%  60.910179640718574%
# 2                Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3               Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4             California  38421464  37.291874687968054%   40.21578881677474%
# 5               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 6               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 7            Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 8               Delaware    926454    8.82476635514019%   64.63271028037383%
# 9   District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 10               Florida  19645772    21.3385426653884%   59.08374880153398%
# ...

# %%
us_census.dtypes
# Out:
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %%
us_census.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      60 non-null     object
#  1   TotalPop   60 non-null     int64
#  2   Hispanic   60 non-null     object
#  3   White      60 non-null     object
#  4   Black      60 non-null     object
#  5   Native     60 non-null     object
#  6   Asian      60 non-null     object
#  7   Pacific    55 non-null     object
#  8   Income     60 non-null     object
#  9   GenderPop  60 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 4.8+ KB

# %%
us_census.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# 0  0.03435374149659865%  $43296.35860306644    2341093M_2489527F
# ...

# %%
us_census.Income = us_census.Income.str.lstrip('$').astype('float')

# %%
us_census.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income            GenderPop
# 0  0.03435374149659865%  43296.358603    2341093M_2489527F
# ...

# %%
us_census[['Men', 'Women']] = us_census.GenderPop.str.split('_', expand=True)

# %%
us_census.drop(['GenderPop'], axis=1, inplace=True)
us_census.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income        Men      Women
# 0  0.03435374149659865%  43296.358603   2341093M   2489527F
# ...

# %%
us_census.Men = us_census.Men.str.rstrip('M')
us_census.Women = us_census.Women.str.rstrip('F')
us_census.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income       Men     Women
# 0  0.03435374149659865%  43296.358603   2341093   2489527
# ...

# %%
us_census.Women = pd.to_numeric(us_census.Women)
us_census.Men = pd.to_numeric(us_census.Men)

# %%
plt.scatter(us_census.Women, us_census.Income)
plt.show()

# %%
us_census.Women.fillna(value=us_census.TotalPop-us_census.Men, inplace=True)

# %%
plt.scatter(us_census.Women, us_census.Income)
plt.show()

# %%
us_census.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
us_census.drop_duplicates(inplace=True)

# %%
plt.scatter(us_census.Women, us_census.Income, color='red')
plt.title('Scatter plot')
plt.show()

# %%
display(us_census.head())
print(us_census.columns)
us_census.info()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income       Men       Women
# 0  0.03435374149659865%  43296.358603   2341093   2489527.0
# ...

# %%
def setting_races(x):
    x = x.str.rstrip('%').astype('float64')
    x = round((us_census.TotalPop * x)/100, 2)
    return x

# %%
us_census.loc[: ,'Hispanic':'Pacific'] = us_census.loc[: ,'Hispanic' : 'Pacific'].apply(setting_races)

# %%
us_census.head(10)
# Out:
#                    State  TotalPop     Hispanic        White       Black  \
# 0                Alabama   4830620    181226.30   2989122.75  1509712.52
# 1                 Alaska    733375     43339.39    446700.03    20890.21
# 2                Arizona   6641928   1963747.19   3793869.27   255779.77
# 3               Arkansas   2958208    183866.66   2104404.39   561135.35
# 4             California  38421464  14328084.21  15451494.82  2181338.82
# 5               Colorado   5278906   1097187.88   3689721.53   187209.90
# 7            Connecticut   3593222    560716.22   2431786.76   371829.04
# 8               Delaware    926454     81757.40    598792.33   192182.93
# 9   District of Columbia    647484     59347.88    214342.52   335244.79
# 10               Florida  19645772   4192121.44  11607458.58  2979414.12
#
#        Native       Asian    Pacific        Income       Men       Women
# 0    21893.88    50733.83    1659.50  43296.358603   2341093   2489527.0
# ...

# %%
us_census.Pacific.fillna(value=us_census.Pacific.sum()/us_census.Pacific.size, inplace=True)

# %%
us_census.head()
# Out:
#         State  TotalPop     Hispanic        White       Black     Native  \
# 0     Alabama   4830620    181226.30   2989122.75  1509712.52   21893.88
# 1      Alaska    733375     43339.39    446700.03    20890.21  120207.63
# 2     Arizona   6641928   1963747.19   3793869.27   255779.77  289260.33
# 3    Arkansas   2958208    183866.66   2104404.39   561135.35   15469.05
# 4  California  38421464  14328084.21  15451494.82  2181338.82  155719.14
#
#         Asian    Pacific        Income       Men       Women
# 0    50733.83    1659.50  43296.358603   2341093   2489527.0
# 1    39971.13    7764.11  70354.743902    384160    349215.0
# 2   191060.30   11133.97  54207.820955   3299088   3342840.0
# 3    33792.67    4344.46  41935.633968   1451913   1506295.0
# 4  5014859.44  135017.01  67264.782303  19087135  19334329.0

# %%
plt.hist((us_census.Hispanic))
# Out:
# (array([43.,  3.,  3.,  0.,  0.,  0.,  0.,  1.,  0.,  1.]),
#  array([1.00838700e+04, 1.44188390e+06, 2.87368394e+06, 4.30548397e+06,
#         5.73728401e+06, 7.16908404e+06, 8.60088407e+06, 1.00326841e+07,
#         1.14644841e+07, 1.28962842e+07, 1.43280842e+07]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist((us_census.White))
# Out:
# (array([16., 12.,  6.,  8.,  2.,  2.,  1.,  3.,  0.,  1.]),
#  array([   27719.33 ,  1570096.879,  3112474.428,  4654851.977,
#          6197229.526,  7739607.075,  9281984.624, 10824362.173,
#         12366739.722, 13909117.271, 15451494.82 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist((us_census.Black))
# Out:
# (array([25.,  6.,  2.,  3.,  3.,  5.,  3.,  0.,  0.,  4.]),
#  array([   3316.46 ,  324082.565,  644848.67 ,  965614.775, 1286380.88 ,
#         1607146.985, 1927913.09 , 2248679.195, 2569445.3  , 2890211.405,
#         3210977.51 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist((us_census.Native))
# Out:
# (array([31.,  8.,  5.,  2.,  1.,  1.,  1.,  0.,  1.,  1.]),
#  array([1.00990000e+02, 2.90169240e+04, 5.79328580e+04, 8.68487920e+04,
#         1.15764726e+05, 1.44680660e+05, 1.73596594e+05, 2.02512528e+05,
#         2.31428462e+05, 2.60344396e+05, 2.89260330e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist((us_census.Asian))
# Out:
# (array([45.,  4.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([2.69437000e+03, 5.03910877e+05, 1.00512738e+06, 1.50634389e+06,
#         2.00756040e+06, 2.50877691e+06, 3.00999341e+06, 3.51120992e+06,
#         4.01242643e+06, 4.51364293e+06, 5.01485944e+06]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist((us_census.Pacific))
# Out:
# (array([44.,  4.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  2.]),
#  array([4.44300000e+01, 1.35416880e+04, 2.70389460e+04, 4.05362040e+04,
#         5.40334620e+04, 6.75307200e+04, 8.10279780e+04, 9.45252360e+04,
#         1.08022494e+05, 1.21519752e+05, 1.35017010e+05]),
#  <BarContainer object of 10 artists>)

# %%
inventory = pd.read_csv('inventory.csv')
inventory
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
staten_island = inventory[inventory.location == 'Staten Island']

# %%
staten_island
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
product_request = staten_island.product_description
product_request
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %%
seed_request = inventory[(inventory.location == 'Brooklyn') & (inventory.product_type == 'seeds')]
seed_request
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
inventory['in_stock'] = inventory.quantity > 0
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price  \
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99
#
#    in_stock
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# ...

# %%
inventory['total_value'] = inventory.price * inventory.quantity
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price  \
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99
#
#    in_stock  total_value
# 0      True        27.96
# 1      True       919.54
# 2      True      1189.15
# 3      True        55.96
# ...

# %%
combine_lambda = lambda row: \
    '{} - {}'.format(row.product_type, row.product_description)

# %%
inventory['full_description'] = inventory.apply(combine_lambda, axis=1)

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...
